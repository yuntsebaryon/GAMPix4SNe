# %%
import ROOT

# %%
f = ROOT.TFile.Open("/Users/yuntse/data/lartpc_rd/gampix/radiologicals/g4/fullgeoanatruth-vd-reduced_g4_00.root")

# %%
events = f.Get("EDepSimEvents")

# %%
event = ROOT.TG4Event()
events.SetBranchAddress("Event",ROOT.AddressOf(event))
# Out:
# 4

# %%
events.GetEntry(15)
# Out:
# 627

# %%
print(f'event number {event.EventId}')
print(f'number of trajectories {event.Trajectories.size()}')
print(f'number of SegmentDetectors {event.SegmentDetectors.size()}')
# Out:
# event number 0
# number of trajectories 1
# number of SegmentDetectors 1

# %%
for p in event.Trajectories:
    print(f'{p.GetTrackId()}, {p.GetParentId()}, {p.GetPDGCode()}, ({p.GetInitialMomentum().Px()}, {p.GetInitialMomentum().Py()}, {p.GetInitialMomentum().Pz()}, {p.GetInitialMomentum().E()})')
    for t in p.Points:
        print(f'p = ({t.GetMomentum().Px()}, {t.GetMomentum().Py()}, {t.GetMomentum().Pz()}), {t.GetProcess()}')
# Out:
# 0, -1, 11, (0.15562552868476995, 0.4228317999128722, 0.49122418273330964, 0.8398970888859952)
# p = (0.15562552868476995, 0.4228317999128722, 0.49122418273330964), 2
# p = (0.0, 0.0, 0.0), 2

# %%
events.GetEntry(31)
# Out:
# 627

# %%
print(f'event number {event.EventId}')
print(f'number of trajectories {event.Trajectories.size()}')
print(f'number of SegmentDetectors {event.SegmentDetectors.size()}')
# Out:
# event number 0
# number of trajectories 1
# number of SegmentDetectors 1

# %%
for p in event.Trajectories:
    print(f'{p.GetTrackId()}, {p.GetParentId()}, {p.GetPDGCode()}, ({p.GetInitialMomentum().Px()}, {p.GetInitialMomentum().Py()}, {p.GetInitialMomentum().Pz()}, {p.GetInitialMomentum().E()})')
    for t in p.Points:
        print(f'p = ({t.GetMomentum().Px()}, {t.GetMomentum().Py()}, {t.GetMomentum().Pz()}), {t.GetProcess()}')
# Out:
# 0, -1, 11, (-0.5256677500849575, -0.5214184852098881, 0.15052339907187512, 0.912129924894088)
# p = (-0.5256677500849575, -0.5214184852098881, 0.15052339907187512), 2
# p = (-0.0, -0.0, -0.0), 2

# %%
events.GetEntry(16)
# Out:
# 627

# %%
print(f'event number {event.EventId}')
print(f'number of trajectories {event.Trajectories.size()}')
print(f'number of SegmentDetectors {event.SegmentDetectors.size()}')
# Out:
# event number 0
# number of trajectories 1
# number of SegmentDetectors 1

# %%
for p in event.Trajectories:
    print(f'{p.GetTrackId()}, {p.GetParentId()}, {p.GetPDGCode()}, ({p.GetInitialMomentum().Px()}, {p.GetInitialMomentum().Py()}, {p.GetInitialMomentum().Pz()}, {p.GetInitialMomentum().E()})')
    for t in p.Points:
        print(f'p = ({t.GetMomentum().Px()}, {t.GetMomentum().Py()}, {t.GetMomentum().Pz()}), {t.GetProcess()}')
# Out:
# 0, -1, 11, (-0.29051530052107327, -0.39912198609054583, -0.027923704472822403, 0.7110535274579439)
# p = (-0.29051530052107327, -0.39912198609054583, -0.027923704472822403), 2
# p = (-0.0, -0.0, -0.0), 2

# %%
events.GetEntries()
# Out:
# 1000
