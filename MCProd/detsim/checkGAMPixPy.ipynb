# %%
import h5py
import numpy as np
import pandas as pd

# %%
fName = '/Users/yuntse/data/lartpc_rd/gampix/detsim/rad_test/rad_fullgeoanatruth-vd-reduced_g4_00.h5'

# %%
with h5py.File(fName, 'r') as f:
    # Print all top-level groups/datasets
    print(list(f.keys()))
    fC = f['coarse_hits']
    fP = f['pixel_hits']
    fM = f['meta']
    
    print(fC.dtype)
    print(fP.dtype)
    print(fM.dtype)
# Out:
# ['coarse_hits', 'meta', 'pixel_hits']
# [('event id', '<u4'), ('tile tpc', '<u4'), ('tile x', '<f4'), ('tile y', '<f4'), ('hit z', '<f4'), ('hit t', '<f4'), ('hit charge', '<f4'), ('attribution', '<f4', (3,)), ('label', '<i4', (3,))]
# [('event id', '<u4'), ('pixel tpc', '<u4'), ('pixel x', '<f4'), ('pixel y', '<f4'), ('hit z', '<f4'), ('hit t', '<f4'), ('hit charge', '<f4'), ('attribution', '<f4', (3,)), ('label', '<i4', (3,))]
# [('event id', '<u4'), ('primary energy', '<f4'), ('deposited charge', '<f4'), ('vertex x', '<f4'), ('vertex y', '<f4'), ('vertex z', '<f4'), ('theta', '<f4'), ('phi', '<f4'), ('primary length', '<f4')]
