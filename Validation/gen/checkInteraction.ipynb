# %%
import ROOT
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Dir = '/Users/yuntse/data/lartpc_rd/gampix/gen'
infile = f'{Dir}/dune/fullgeoanatruth-vd1x8x14-1000.root'

# %%
tName = 'fullgeoanatruth/FullGeoAnaTruth'
fRad = ROOT.TFile( infile )
tRad = fRad.Get(tName)

# %%
# rdf = ROOT.RDataFrame(tName, infile)
# np_dict = rdf.AsNumpy()
# df = pd.DataFrame(np_dict)

# print(df.head())

# %%
Interactions = []
for iPart, iEvt in enumerate( tRad ):
    label = str(iEvt.label)
    # print(label)
    if label not in Interactions:
        Interactions.append( label )
        # print("                ==> ", iEvt.label)
    # if iEvt.event > 1: break

# %%
print(Interactions)
# Out:
# ['Ar39GenInLAr', 'Kr85GenInLAr', 'Ar42GenInLAr', 'K42From42ArGenInLAr', 'Rn222ChainRn222GenInLAr', 'Rn222ChainPo218GenInLAr', 'Rn222ChainPb214GenInLAr', 'Rn222ChainBi214GenInLAr', 'Rn222ChainPb210GenInLAr', 'Rn220ChainPb212GenInLAr', 'K40GenInCathode', 'U238ChainGenInCathode', 'Th232ChainGenInCathode', 'K42From42ArGenInUpperMesh', 'Rn222ChainFromPo218GenInUpperMesh', 'Rn222ChainFromPb214GenInUpperMesh', 'Rn222ChainFromBi214GenInUpperMesh', 'Rn222ChainFromPb210GenInUpperMesh', 'Rn222ChainFromBi210GenInUpperMesh', 'Rn220ChainFromPb212GenInUpperMesh', 'K40GenInAnode', 'U238ChainGenInAnode', 'Th232ChainGenInAnode', 'CavernwallGammasAtLAr', 'foamGammasAtLAr', 'Rn222ChainGenInPDS', 'CavernwallNeutronsAtLAr', 'CavernNGammasAtLAr', 'CryostatNGammasAtLAr']

# %%
type(iEvt.label)
# Out:
# <class cppyy.gbl.std.string at 0x30e877c10>
