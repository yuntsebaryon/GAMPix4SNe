# %% [markdown]
# # Event Display: Supernova Neutrino + Radilogicals

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
detector_bounds = [[-150, 150], [895.94, 1195.94], [-325, 325]] # cm (y, z, x)
def draw_boundaries(ax):
    """
    Draw the detector boundaries as a wireframe
    not needed, but pretty
    """
    boundKwargs = {'color': 'black',
                   'ls': '--'}
    
    ax.plot([detector_bounds[0][0], detector_bounds[0][1]],
            [detector_bounds[1][0], detector_bounds[1][0]],
            [detector_bounds[2][0], detector_bounds[2][0]],
            **boundKwargs)
    ax.plot([detector_bounds[0][0], detector_bounds[0][1]],
            [detector_bounds[1][1], detector_bounds[1][1]],
            [detector_bounds[2][0], detector_bounds[2][0]],
            **boundKwargs)
    ax.plot([detector_bounds[0][0], detector_bounds[0][1]],
            [detector_bounds[1][0], detector_bounds[1][0]],
            [detector_bounds[2][1], detector_bounds[2][1]],
            **boundKwargs)
    ax.plot([detector_bounds[0][0], detector_bounds[0][1]],
            [detector_bounds[1][1], detector_bounds[1][1]],
            [detector_bounds[2][1], detector_bounds[2][1]],
            **boundKwargs)

    ax.plot([detector_bounds[0][0], detector_bounds[0][0]],
            [detector_bounds[1][0], detector_bounds[1][1]],
            [detector_bounds[2][0], detector_bounds[2][0]],
            **boundKwargs)
    ax.plot([detector_bounds[0][1], detector_bounds[0][1]],
            [detector_bounds[1][0], detector_bounds[1][1]],
            [detector_bounds[2][0], detector_bounds[2][0]],
            **boundKwargs)
    ax.plot([detector_bounds[0][0], detector_bounds[0][0]],
            [detector_bounds[1][0], detector_bounds[1][1]],
            [detector_bounds[2][1], detector_bounds[2][1]],
            **boundKwargs)
    ax.plot([detector_bounds[0][1], detector_bounds[0][1]],
            [detector_bounds[1][0], detector_bounds[1][1]],
            [detector_bounds[2][1], detector_bounds[2][1]],
            **boundKwargs)

    ax.plot([detector_bounds[0][0], detector_bounds[0][0]],
            [detector_bounds[1][0], detector_bounds[1][0]],
            [detector_bounds[2][0], detector_bounds[2][1]],
            **boundKwargs)
    ax.plot([detector_bounds[0][0], detector_bounds[0][0]],
            [detector_bounds[1][1], detector_bounds[1][1]],
            [detector_bounds[2][0], detector_bounds[2][1]],
            **boundKwargs)
    ax.plot([detector_bounds[0][1], detector_bounds[0][1]],
            [detector_bounds[1][0], detector_bounds[1][0]],
            [detector_bounds[2][0], detector_bounds[2][1]],
            **boundKwargs)
    ax.plot([detector_bounds[0][1], detector_bounds[0][1]],
            [detector_bounds[1][1], detector_bounds[1][1]],
            [detector_bounds[2][0], detector_bounds[2][1]],
            **boundKwargs)

    return ax

# %%
SNFile = '/Users/yuntse/data/lartpc_rd/gampix/mixed/garching/nh/g4/rad_nueArCC_garching_nh_mxDir_x0_g4_0000.csv'

# %%
SNEvent = pd.read_csv( SNFile )
SNEvent
# Out:
#               run  subrun  event  isSignal  pdgCode  trackID  motherID  \
# 0        20000047       0      0         1       22        5         0
# 1        20000047       0      0         1       22        5         0
# 2        20000047       0      0         1       22        5         0
# 3        20000047       0      0         1       22        5         0
# 4        20000047       0      0         1       22        5         0
# ...           ...     ...    ...       ...      ...      ...       ...
# 1332923  20000047       0     99         0       11        5         0
# 1332924  20000047       0     99         0       11        4         0
# 1332925  20000047       0     99         0       11        3         0
# 1332926  20000047       0     99         0       11        2         0
# 1332927  20000047       0     99         0       11        1         0
#
#            startE        dE       startX       startY        startZ  \
# 0        3.333308  0.000000     0.000000     0.000000  10459.400000
# 1        3.185231  0.000000    -5.810314    72.414482  10531.814482
# 2        0.761142  0.000000    -5.937956    94.448864  10549.555238
# 3        0.278398  0.000000    14.194428   142.953046  10532.514350
# 4        0.264142  0.000000    -1.663884   126.215293  10491.267978
# ...           ...       ...          ...          ...           ...
# 1332923  0.695048  0.184049 -3139.798376  1100.997435   9918.769793
# 1332924  0.720186  0.209187   536.707461   285.030856   9099.981962
# 1332925  0.671502  0.160503   269.648990   998.813662  10623.686770
# 1332926  0.525029  0.014030   345.249813 -1347.463120  10227.896134
# 1332927  0.635958  0.124959 -3461.574236  1366.676502  11552.260280
#
#                startT         endX         endY          endZ          endT
# 0        0.000000e+00    -5.810314    72.414482  10531.814482  3.421508e-01
# 1        3.421508e-01    -5.937956    94.448864  10549.555238  4.365126e-01
# 2        4.365126e-01    14.194428   142.953046  10532.514350  6.206799e-01
# 3        6.206799e-01    -1.663884   126.215293  10491.267978  7.783009e-01
# 4        7.783009e-01    -6.702821   126.004391  10484.934070  8.053080e-01
# ...               ...          ...          ...           ...           ...
# 1332923 -6.692297e+05 -3139.816681  1101.106655   9918.760129 -6.692297e+05
# 1332924 -1.313929e+06   536.806502   285.051483   9099.889737 -1.313929e+06
# 1332925 -1.673047e+06   269.569062   998.817418  10623.725165 -1.673047e+06
# 1332926 -2.876962e+06   345.250163 -1347.464340  10227.895881 -2.876962e+06
# 1332927 -1.153159e+06 -3461.531488  1366.672234  11552.299866 -1.153159e+06
#
# [1332928 rows x 17 columns]

# %% [markdown]
# Pick an event

# %%
iEvt = 0

# %%
Evt = SNEvent[(SNEvent.event==iEvt)]
Evt
# Out:
#             run  subrun  event  isSignal  pdgCode  trackID  motherID  \
# 0      20000047       0      0         1       22        5         0
# 1      20000047       0      0         1       22        5         0
# 2      20000047       0      0         1       22        5         0
# 3      20000047       0      0         1       22        5         0
# 4      20000047       0      0         1       22        5         0
# ...         ...     ...    ...       ...      ...      ...       ...
# 13358  20000047       0      0         0       11        4         0
# 13359  20000047       0      0         0       11        3         0
# 13360  20000047       0      0         0       11        3         0
# 13361  20000047       0      0         0       11        2         0
# 13362  20000047       0      0         0       11        1         0
#
#          startE        dE       startX       startY        startZ  \
# 0      3.333308  0.000000     0.000000     0.000000  10459.400000
# 1      3.185231  0.000000    -5.810314    72.414482  10531.814482
# 2      0.761142  0.000000    -5.937956    94.448864  10549.555238
# 3      0.278398  0.000000    14.194428   142.953046  10532.514350
# 4      0.264142  0.000000    -1.663884   126.215293  10491.267978
# ...         ...       ...          ...          ...           ...
# 13358  0.615369  0.104370  2115.042640   281.754928  10907.928174
# 13359  0.905751  0.299933 -3968.055752 -1360.269345  10596.814227
# 13360  0.605818  0.094819 -3968.050534 -1360.025481  10597.093769
# 13361  0.521284  0.010285  -790.422897  -397.160146  10046.570385
# 13362  0.968072  0.457073  2801.280615  -553.875304   9432.981567
#
#              startT         endX         endY          endZ          endT
# 0      0.000000e+00    -5.810314    72.414482  10531.814482  3.421508e-01
# 1      3.421508e-01    -5.937956    94.448864  10549.555238  4.365126e-01
# 2      4.365126e-01    14.194428   142.953046  10532.514350  6.206799e-01
# 3      6.206799e-01    -1.663884   126.215293  10491.267978  7.783009e-01
# 4      7.783009e-01    -6.702821   126.004391  10484.934070  8.053080e-01
# ...             ...          ...          ...           ...           ...
# 13358  2.945519e+06  2115.053138   281.743657  10907.968367  2.945519e+06
# 13359 -3.314277e+06 -3968.050534 -1360.025481  10597.093769 -3.314277e+06
# 13360 -3.314277e+06 -3968.080824 -1360.043318  10597.083837 -3.314277e+06
# 13361 -3.711309e+06  -790.422537  -397.159617  10046.569989 -3.711309e+06
# 13362 -5.638310e+05  2801.297575  -553.477741   9433.217706 -5.638310e+05
#
# [13363 rows x 17 columns]

# %% [markdown]
# Select the segments which deposit energy for signals and radiologicals

# %%
sig = Evt[(Evt.isSignal==1)&(Evt.pdgCode!=12)&(Evt.dE>0.)]

# %% [markdown]
# For the radiologicals, we will see the ones drifting to the CRP at the time window of the neutrino interactions $\pm$ 100 cm.
# In this case, the interaction happens at t = 0ns, x = 0cm.
# The signal at x = 0cm will arrive at the CRP at t = 2.03ms.
# The signal at x = 100cm will arrive at the CRP at t = 1406250ns, and similarly, the signal at x = -100cm will arrive at the CRP at t = 2656250ns.

# %%
rad = Evt[(Evt.isSignal==0)&(Evt.dE>0.)&(Evt.startT+(3250-Evt.startX)/1.6*1000>1406250)&(Evt.startT+(3250-Evt.startX)/1.6*1000<2656250)]

# %%
fig = plt.figure( figsize = (12, 9))  
ax = fig.add_subplot( 1, 1, 1, projection = '3d' )

ax.scatter( sig['startY']/10, sig['startZ']/10, sig['startX']/10, label = 'Supernova neutrino')
ax.scatter( rad['startY']/10, rad['startZ']/10, rad['startX']/10, c = 'gold', label = 'Radiologicals')
                    
ax.scatter( 0., 1045.94, 0., s = 800, c = '#DC143C', label = 'Interaction vertex', marker = '*' )
draw_boundaries(ax)
ax.set_xlabel('y [cm]', fontsize = 18, labelpad = 10)
ax.set_ylabel('z [cm]', fontsize = 18, labelpad = 20)
ax.set_zlabel('x [cm]', fontsize = 18, labelpad = 10)
ax.tick_params( axis = 'x', labelsize = 18 )
ax.tick_params( axis = 'y', labelsize = 18 )
ax.tick_params( axis = 'z', labelsize = 18 )
ax.legend( ncol = 2, fontsize = 14, loc = 'upper left' )
ax.set_xlim( [-160, 160])
ax.set_ylim( [885, 1205])
ax.set_zlim( [-335, 335])
# fig.subplots_adjust( right = 0.9)

fig.savefig('SNRad.pdf')
fig.savefig('SNRad.png')

# %%
sig['startY'].max(), sig['startY'].min(), sig['startZ'].max(), sig['startZ'].min()
# Out:
# (327.4631170176786, -66.74000639262077, 10672.300707882963, 10394.40863169)

# %%
fig = plt.figure( figsize = (12, 9))  
ax = fig.add_subplot( 1, 1, 1, projection = '3d' )

ax.scatter( sig['startY']/10, sig['startZ']/10, sig['startX']/10, label = 'Supernova neutrino')
ax.scatter( rad['startY']/10, rad['startZ']/10, rad['startX']/10, c = 'gold', label = 'Radiologicals')
                    
ax.scatter( 0., 1045.94, 0., s = 800, c = '#DC143C', label = 'Interaction vertex', marker = '*' )

ax.set_xlabel('y [cm]', fontsize = 18, labelpad = 10)
ax.set_ylabel('z [cm]', fontsize = 18, labelpad = 20)
ax.set_zlabel('x [cm]', fontsize = 18, labelpad = 10)
ax.tick_params( axis = 'x', labelsize = 18 )
ax.tick_params( axis = 'y', labelsize = 18 )
ax.tick_params( axis = 'z', labelsize = 18 )
ax.legend( ncol = 2, fontsize = 14, loc = 'upper left' )
ax.set_xlim( [-16, 50])
ax.set_ylim( [1000, 1100])
ax.set_zlim( [-335, 335])
# Out:
# (-335.0, 335.0)

# %%
rad['startX'].min(), rad['startX'].max()
# Out:
# (-4230.07582345009, 4139.71634048892)
