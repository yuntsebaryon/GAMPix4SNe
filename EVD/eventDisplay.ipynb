# %% [markdown]
# # Event Display: Supernova Neutrino + Radilogicals

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
detector_bounds = [[-150, 150], [895.94, 1195.94], [-325, 325]] # cm (y, z, x)
def draw_boundaries(ax):
    """
    Draw the detector boundaries as a wireframe
    not needed, but pretty
    """
    boundKwargs = {'color': 'black',
                   'ls': '--'}
    
    ax.plot([detector_bounds[0][0], detector_bounds[0][1]],
            [detector_bounds[1][0], detector_bounds[1][0]],
            [detector_bounds[2][0], detector_bounds[2][0]],
            **boundKwargs)
    ax.plot([detector_bounds[0][0], detector_bounds[0][1]],
            [detector_bounds[1][1], detector_bounds[1][1]],
            [detector_bounds[2][0], detector_bounds[2][0]],
            **boundKwargs)
    ax.plot([detector_bounds[0][0], detector_bounds[0][1]],
            [detector_bounds[1][0], detector_bounds[1][0]],
            [detector_bounds[2][1], detector_bounds[2][1]],
            **boundKwargs)
    ax.plot([detector_bounds[0][0], detector_bounds[0][1]],
            [detector_bounds[1][1], detector_bounds[1][1]],
            [detector_bounds[2][1], detector_bounds[2][1]],
            **boundKwargs)

    ax.plot([detector_bounds[0][0], detector_bounds[0][0]],
            [detector_bounds[1][0], detector_bounds[1][1]],
            [detector_bounds[2][0], detector_bounds[2][0]],
            **boundKwargs)
    ax.plot([detector_bounds[0][1], detector_bounds[0][1]],
            [detector_bounds[1][0], detector_bounds[1][1]],
            [detector_bounds[2][0], detector_bounds[2][0]],
            **boundKwargs)
    ax.plot([detector_bounds[0][0], detector_bounds[0][0]],
            [detector_bounds[1][0], detector_bounds[1][1]],
            [detector_bounds[2][1], detector_bounds[2][1]],
            **boundKwargs)
    ax.plot([detector_bounds[0][1], detector_bounds[0][1]],
            [detector_bounds[1][0], detector_bounds[1][1]],
            [detector_bounds[2][1], detector_bounds[2][1]],
            **boundKwargs)

    ax.plot([detector_bounds[0][0], detector_bounds[0][0]],
            [detector_bounds[1][0], detector_bounds[1][0]],
            [detector_bounds[2][0], detector_bounds[2][1]],
            **boundKwargs)
    ax.plot([detector_bounds[0][0], detector_bounds[0][0]],
            [detector_bounds[1][1], detector_bounds[1][1]],
            [detector_bounds[2][0], detector_bounds[2][1]],
            **boundKwargs)
    ax.plot([detector_bounds[0][1], detector_bounds[0][1]],
            [detector_bounds[1][0], detector_bounds[1][0]],
            [detector_bounds[2][0], detector_bounds[2][1]],
            **boundKwargs)
    ax.plot([detector_bounds[0][1], detector_bounds[0][1]],
            [detector_bounds[1][1], detector_bounds[1][1]],
            [detector_bounds[2][0], detector_bounds[2][1]],
            **boundKwargs)

    return ax

# %%
SNFile = '/Users/yuntse/data/lartpc_rd/gampix/mixed/garching/nh/g4/rad_nueArCC_garching_nh_mxDir_xpos000cm_g4_0000.csv'

# %%
SNEvent = pd.read_csv( SNFile )
SNEvent
# Out:
#               run  subrun  event  isSignal  pdgCode  trackID  motherID  \
# 0        20000047       0      0         1       22        7         0
# 1        20000047       0      0         1       11        8         7
# 2        20000047       0      0         1       22        6         0
# 3        20000047       0      0         1       22        6         0
# 4        20000047       0      0         1       22        6         0
# ...           ...     ...    ...       ...      ...      ...       ...
# 6649109  20000047       0     99         0       11        5         0
# 6649110  20000047       0     99         0       11        4         0
# 6649111  20000047       0     99         0       11        3         0
# 6649112  20000047       0     99         0       11        2         0
# 6649113  20000047       0     99         0       11        1         0
#
#            startE        dE       startX       startY        startZ  \
# 0        0.029819  0.003206     0.000000     0.000000  10459.400000
# 1        0.537612  0.026613     0.175919     0.163400  10459.745080
# 2        0.770030  0.000000     0.000000     0.000000  10459.400000
# 3        0.473067  0.000000    45.566604  -146.272649  10396.064557
# 4        0.345832  0.000000   -30.366908  -246.878350  10379.674710
# ...           ...       ...          ...          ...           ...
# 6649109  0.776668  0.265669 -4180.281782  -827.292600  11566.297894
# 6649110  0.656892  0.145893  1251.289916  1467.251491  11667.599821
# 6649111  0.744298  0.233299   672.863850   724.648611  11925.884135
# 6649112  0.726195  0.215196  -773.284940   714.348987   9412.212709
# 6649113  0.596181  0.085182  2964.510354   392.995331  11005.261049
#
#                startT         endX         endY          endZ          endT
# 0        0.000000e+00     0.175919     0.163400  10459.745080  1.402270e-03
# 1        1.402270e-03     0.172723     0.161142  10459.744404  1.444906e-03
# 2        0.000000e+00    45.566604  -146.272649  10396.064557  5.529863e-01
# 3        5.529863e-01   -30.366908  -246.878350  10379.674710  9.769676e-01
# 4        9.769676e-01   -32.773224  -249.422676  10383.204528  9.935533e-01
# ...               ...          ...          ...           ...           ...
# 6649109 -3.870495e+06 -4180.127162  -827.212932  11566.397945 -3.870495e+06
# 6649110  2.899374e+06  1251.302020  1467.241798  11667.525681  2.899374e+06
# 6649111 -3.490101e+06   672.949103   724.510120  11925.897372 -3.490101e+06
# 6649112 -3.729915e+06  -773.315315   714.447213   9412.112888 -3.729915e+06
# 6649113  4.244135e+06  2964.480673   392.998924  11005.255641  4.244135e+06
#
# [6649114 rows x 17 columns]

# %% [markdown]
# Pick an event

# %%
iEvt = 0

# %%
Evt = SNEvent[(SNEvent.event==iEvt)]
Evt
# Out:
#             run  subrun  event  isSignal  pdgCode  trackID  motherID  \
# 0      20000047       0      0         1       22        7         0
# 1      20000047       0      0         1       11        8         7
# 2      20000047       0      0         1       22        6         0
# 3      20000047       0      0         1       22        6         0
# 4      20000047       0      0         1       22        6         0
# ...         ...     ...    ...       ...      ...      ...       ...
# 14472  20000047       0      0         0       11        5         0
# 14473  20000047       0      0         0       11        4         0
# 14474  20000047       0      0         0       11        3         0
# 14475  20000047       0      0         0       11        2         0
# 14476  20000047       0      0         0       11        1         0
#
#          startE        dE       startX       startY        startZ  \
# 0      0.029819  0.003206     0.000000     0.000000  10459.400000
# 1      0.537612  0.026613     0.175919     0.163400  10459.745080
# 2      0.770030  0.000000     0.000000     0.000000  10459.400000
# 3      0.473067  0.000000    45.566604  -146.272649  10396.064557
# 4      0.345832  0.000000   -30.366908  -246.878350  10379.674710
# ...         ...       ...          ...          ...           ...
# 14472  0.582694  0.071695   135.925834   493.442978  11774.116156
# 14473  0.521306  0.010307  3226.557287  -879.793719  10568.030340
# 14474  0.602932  0.091933  2686.480023  1272.980453  10626.770558
# 14475  0.783480  0.272481 -3959.633248  1466.412062  11036.782336
# 14476  0.613955  0.102956 -3091.605411  -260.656906  11131.157883
#
#              startT         endX         endY          endZ          endT
# 0      0.000000e+00     0.175919     0.163400  10459.745080  1.402270e-03
# 1      1.402270e-03     0.172723     0.161142  10459.744404  1.444906e-03
# 2      0.000000e+00    45.566604  -146.272649  10396.064557  5.529863e-01
# 3      5.529863e-01   -30.366908  -246.878350  10379.674710  9.769676e-01
# 4      9.769676e-01   -32.773224  -249.422676  10383.204528  9.935533e-01
# ...             ...          ...          ...           ...           ...
# 14472  2.562904e+06   135.929513   493.464071  11774.123264  2.562904e+06
# 14473  1.677721e+06  3226.557926  -879.794119  10568.030377  1.677721e+06
# 14474 -1.905684e+06  2686.501913  1272.969232  10626.746167 -1.905684e+06
# 14475  3.642348e+06 -3959.684266  1466.280468  11036.936281  3.642348e+06
# 14476  3.679103e+06 -3091.596973  -260.630306  11131.189343  3.679103e+06
#
# [14477 rows x 17 columns]

# %% [markdown]
# Select the segments which deposit energy for signals and radiologicals

# %%
sig = Evt[(Evt.isSignal==1)&(Evt.pdgCode!=12)&(Evt.dE>0.)]

# %% [markdown]
# For the radiologicals, we will see the ones drifting to the CRP at the time window of the neutrino interactions $\pm$ 100 cm.
# In this case, the interaction happens at t = 0ns, x = 0cm.
# The signal at x = 0cm will arrive at the CRP at t = 2.03ms.
# The signal at x = 100cm will arrive at the CRP at t = 1406250ns, and similarly, the signal at x = -100cm will arrive at the CRP at t = 2656250ns.

# %%
rad = Evt[(Evt.isSignal==0)&(Evt.dE>0.)&(Evt.startT+(3250-Evt.startX)/1.6*1000>1406250)&(Evt.startT+(3250-Evt.startX)/1.6*1000<2656250)]

# %%
fig = plt.figure( figsize = (12, 9))  
ax = fig.add_subplot( 1, 1, 1, projection = '3d' )

ax.scatter( sig['startY']/10, sig['startZ']/10, sig['startX']/10, label = 'Supernova neutrino')
ax.scatter( rad['startY']/10, rad['startZ']/10, rad['startX']/10, c = 'gold', label = 'Radiologicals')
                    
ax.scatter( 0., 1045.94, 0., s = 800, c = '#DC143C', label = 'Interaction vertex', marker = '*' )
draw_boundaries(ax)
ax.set_xlabel('y [cm]', fontsize = 18, labelpad = 10)
ax.set_ylabel('z [cm]', fontsize = 18, labelpad = 20)
ax.set_zlabel('x [cm]', fontsize = 18, labelpad = 10)
ax.tick_params( axis = 'x', labelsize = 18 )
ax.tick_params( axis = 'y', labelsize = 18 )
ax.tick_params( axis = 'z', labelsize = 18 )
ax.legend( ncol = 2, fontsize = 14, loc = 'upper left' )
ax.set_xlim( [-160, 160])
ax.set_ylim( [885, 1205])
ax.set_zlim( [-335, 335])
# fig.subplots_adjust( right = 0.9)

fig.savefig('SNRad.pdf')
fig.savefig('SNRad.png')

# %%
sig['startY'].max(), sig['startY'].min(), sig['startZ'].max(), sig['startZ'].min()
# Out:
# (41.55524478152222,
#  -393.86693624311226,
#  10467.195157253387,
#  10287.775408514304)

# %%
fig = plt.figure( figsize = (12, 9))  
ax = fig.add_subplot( 1, 1, 1, projection = '3d' )

ax.scatter( sig['startY']/10, sig['startZ']/10, sig['startX']/10, label = 'Supernova neutrino')
ax.scatter( rad['startY']/10, rad['startZ']/10, rad['startX']/10, c = 'gold', label = 'Radiologicals')
                    
ax.scatter( 0., 1045.94, 0., s = 800, c = '#DC143C', label = 'Interaction vertex', marker = '*' )

ax.set_xlabel('y [cm]', fontsize = 18, labelpad = 10)
ax.set_ylabel('z [cm]', fontsize = 18, labelpad = 20)
ax.set_zlabel('x [cm]', fontsize = 18, labelpad = 10)
ax.tick_params( axis = 'x', labelsize = 18 )
ax.tick_params( axis = 'y', labelsize = 18 )
ax.tick_params( axis = 'z', labelsize = 18 )
ax.legend( ncol = 2, fontsize = 14, loc = 'upper left' )
ax.set_xlim( [-41, 10])
ax.set_ylim( [1000, 1100])
ax.set_zlim( [-335, 335])
# Out:
# (-335.0, 335.0)

# %%
rad['startX'].min(), rad['startX'].max()
# Out:
# (-4240.71317601204, 4090.318102238364)
